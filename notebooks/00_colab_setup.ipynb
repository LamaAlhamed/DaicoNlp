# %% [markdown]
# # SDA-AIE-211 — Google Colab Setup
# This notebook only prepares a GPU runtime for the **same GitHub repository** used locally. It contains no lab solutions.
#
# Use it when a lab needs GPU training (primarily Labs 3–4). Do not use Colab GPU numbers as the Lab 7 CPU latency evidence.

# %% [markdown]
# ## 1. Select a GPU runtime
# In Colab choose **Runtime → Change runtime type → T4 GPU** (or another available GPU), then run the next cell.

# %%
import sys, platform
import torch

print('Python:', sys.version.split()[0])
print('Platform:', platform.platform())
print('CUDA available:', torch.cuda.is_available())
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU only')
assert torch.cuda.is_available(), 'Enable a GPU runtime before Labs 3–4.'
# Out:
# Python: 3.13.15
# Platform: Linux-6.6.122+-x86_64-with-glibc2.35
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## 2. Clone your own course repository
# Replace `YOUR_GITHUB_USERNAME` with your GitHub username. For a private repository, authenticate using the method approved for your cohort; do not paste a token into a shared notebook.

# %%
GITHUB_USERNAME = 'LamaAlhamed'
REPO_NAME = 'DaicoNlp'

repo_url = f'https://github.com/{GITHUB_USERNAME}/{REPO_NAME}.git'
print(repo_url)
# !git clone $repo_url
# Out:
# https://github.com/LamaAlhamed/DaicoNlp.git
# Cloning into 'DaicoNlp'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (215/215), done.
# remote: Total 227 (delta 83), reused 83 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (227/227), 688.90 KiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %%
# After cloning, enter the project directory.
# %cd DaicoNlp
# Out:
# /content/DaicoNlp

# %%
# !pip install -q "transformers>=4.40,<5" datasets scikit-learn sentencepiece accelerate seqeval
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 107.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 109.1 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.40.0 requires huggingface-hub<2.0,>=1.23.0, but you have huggingface-hub 0.36.2 which is incompatible.
# gradio 6.26.0 requires huggingface-hub<2.0,>=1.16.0, but you have huggingface-hub 0.36.2 which is incompatible.

# %%
import os
os.environ['PYTHONPATH'] = '/content/DaicoNlp/src'

# %% [markdown]
# ## 3. Install the same project dependencies
# The repository remains the source of truth. Colab installs from the same `requirements.txt` and editable package metadata.

# %%
# !python -m pip install --upgrade pip -q
# !python -m pip install -r requirements.txt -q
# !python -m pip install -e . -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for seqeval (pyproject.toml) ... done
#   Building wheel for docopt (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.40.0 requires huggingface-hub<2.0,>=1.23.0, but you have huggingface-hub 0.36.2 which is incompatible.
# gradio 6.26.0 requires huggingface-hub<2.0,>=1.16.0, but you have huggingface-hub 0.36.2 which is incompatible.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for bayan-nlp-course (pyproject.toml) ... done

# %%
# !python scripts/doctor.py
# Out:
# ✗ Python 3.12: 3.13.15
# ✓ transformers: 4.57.6
# ✓ spacy: 3.8.16
# ✓ pandas: 2.2.3
# ✓ pytest: 8.4.2
# ✓ sklearn: 1.9.0
# ✓ data/raw/bayan_feedback.csv
# ✓ data/raw/bayan_raw_sample.csv
# ✓ data/eval/pii_test_set.csv
# ✓ data/eval/arabic_normalize_golden.csv
# ✓ data/models/bayan_ner.conll
# ✓ data/models/bayan_qa.json
# ✓ data/search/bayan_cases.csv
# ✓ data/search/bayan_queries.jsonl
#
# FIX FAILED CHECKS BEFORE THE LAB

# %%
# !python scripts/train_classifier.py --output-dir artifacts/topic_classifier
# Out:
# 2026-09-08 18:00:17.933175: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 126kB/s]
# config.json: 100% 615/615 [00:00<00:00, 3.03MB/s]
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:01<00:00, 4.44MB/s]
# tokenizer.json: 9.10MB [00:00, 50.3MB/s]
# Map: 100% 8400/8400 [00:00<00:00, 20505.20 examples/s]
# Map: 100% 2400/2400 [00:00<00:00, 20032.66 examples/s]
# Map: 100% 1200/1200 [00:00<00:00, 21937.88 examples/s]
# model.safetensors: 100% 1.12G/1.12G [00:22<00:00, 50.4MB/s]
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# {'loss': 1.9294, 'grad_norm': 12.065735816955566, 'learning_rate': 1.9377777777777778e-05, 'epoch': 0.1}
# {'loss': 0.9059, 'grad_norm': 7.794625759124756, 'learning_rate': 1.8742857142857143e-05, 'epoch': 0.19}
# {'loss': 0.253, 'grad_norm': 1.9924546480178833, 'learning_rate': 1.810793650793651e-05, 'epoch': 0.29}
# {'loss': 0.0675, 'grad_norm': 0.6105025410652161, 'learning_rate': 1.7473015873015874e-05, 'epoch': 0.38}
# {'loss': 0.021, 'grad_norm': 0.3248665928840637, 'learning_rate': 1.683809523809524e-05, 'epoch': 0.48}
# {'loss': 0.0077, 'grad_norm': 0.09566771984100342, 'learning_rate': 1.6203174603174604e-05, 'epoch': 0.57}
# {'loss': 0.0055, 'grad_norm': 0.041913412511348724, 'learning_rate': 1.556825396825397e-05, 'epoch': 0.67}
# {'loss': 0.0052, 'grad_norm': 0.03582882136106491, 'learning_rate': 1.4933333333333335e-05, 'epoch': 0.76}
# {'loss': 0.0103, 'grad_norm': 0.03571707382798195, 'learning_rate': 1.42984126984127e-05, 'epoch': 0.86}
# {'loss': 0.006, 'grad_norm': 0.02292669378221035, 'learning_rate': 1.3663492063492065e-05, 'epoch': 0.95}
#  33% 525/1575 [00:57<01:58,  8.83it/s]
#   0% 0/150 [00:00<?, ?it/s]
#   4% 6/150 [00:00<00:02, 50.57it/s]
#   8% 12/150 [00:00<00:03, 45.26it/s]
#  11% 17/150 [00:00<00:03, 42.28it/s]
#  15% 22/150 [00:00<00:03, 40.06it/s]
#  18% 27/150 [00:00<00:03, 40.72it/s]
#  21% 32/150 [00:00<00:02, 41.81it/s]
#  25% 37/150 [00:00<00:02, 42.78it/s]
#  28% 42/150 [00:00<00:02, 43.78it/s]
#  31% 47/150 [00:01<00:02, 42.67it/s]
#  35% 52/150 [00:01<00:02, 42.65it/s]
#  38% 57/150 [00:01<00:02, 42.56it/s]
#  41% 62/150 [00:01<00:02, 43.03it/s]
#  45% 67/150 [00:01<00:01, 44.09it/s]
#  48% 72/150 [00:01<00:01, 44.16it/s]
#  51% 77/150 [00:01<00:01, 43.18it/s]
#  55% 82/150 [00:01<00:01, 43.71it/s]
#  58% 87/150 [00:02<00:01, 43.48it/s]
#  61% 92/150 [00:02<00:01, 42.89it/s]
#  65% 97/150 [00:02<00:01, 43.32it/s]
#  68% 102/150 [00:02<00:01, 43.55it/s]
#  71% 107/150 [00:02<00:01, 42.75it/s]
#  75% 112/150 [00:02<00:00, 42.03it/s]
#  78% 117/150 [00:02<00:00, 42.30it/s]
#  81% 122/150 [00:02<00:00, 42.41it/s]
#  85% 127/150 [00:02<00:00, 42.26it/s]
#  88% 132/150 [00:03<00:00, 42.28it/s]
#  91% 137/150 [00:03<00:00, 41.81it/s]
#  95% 142/150 [00:03<00:00, 42.15it/s]
#
# {'eval_loss': 0.0010999072110280395, 'eval_macro_f1': 1.0, 'eval_runtime': 3.6168, 'eval_samples_per_second': 663.575, 'eval_steps_per_second': 41.473, 'epoch': 1.0}
#  33% 525/1575 [01:01<01:58,  8.83it/s]
# 100% 150/150 [00:03<00:00, 42.34it/s]
# {'loss': 0.0056, 'grad_norm': 0.025029443204402924, 'learning_rate': 1.302857142857143e-05, 'epoch': 1.05}
# {'loss': 0.0018, 'grad_norm': 0.02663293667137623, 'learning_rate': 1.2393650793650796e-05, 'epoch': 1.14}
# {'loss': 0.0016, 'grad_norm': 0.020408757030963898, 'learning_rate': 1.1758730158730161e-05, 'epoch': 1.24}
# {'loss': 0.0037, 'grad_norm': 0.03139125928282738, 'learning_rate': 1.1123809523809526e-05, 'epoch': 1.33}
# {'loss': 0.0013, 'grad_norm': 0.012559263035655022, 'learning_rate': 1.048888888888889e-05, 'epoch': 1.43}
# {'loss': 0.0012, 'grad_norm': 0.016165565699338913, 'learning_rate': 9.853968253968255e-06, 'epoch': 1.52}
# {'loss': 0.0011, 'grad_norm': 0.01938660442829132, 'learning_rate': 9.21904761904762e-06, 'epoch': 1.62}
# {'loss': 0.001, 'grad_norm': 0.013650971464812756, 'learning_rate': 8.584126984126984e-06, 'epoch': 1.71}
# {'loss': 0.001, 'grad_norm': 0.009473043493926525, 'learning_rate': 7.94920634920635e-06, 'epoch': 1.81}
# {'loss': 0.001, 'grad_norm': 0.009777258150279522, 'learning_rate': 7.314285714285715e-06, 'epoch': 1.9}
# {'loss': 0.0009, 'grad_norm': 0.009648749604821205, 'learning_rate': 6.67936507936508e-06, 'epoch': 2.0}
#  67% 1050/1575 [02:42<01:03,  8.21it/s]
#   0% 0/150 [00:00<?, ?it/s]
#   4% 6/150 [00:00<00:02, 48.42it/s]
#   7% 11/150 [00:00<00:03, 41.51it/s]
#  11% 16/150 [00:00<00:03, 39.07it/s]
#  13% 20/150 [00:00<00:03, 37.12it/s]
#  16% 24/150 [00:00<00:03, 37.78it/s]
#  19% 28/150 [00:00<00:03, 38.42it/s]
#  22% 33/150 [00:00<00:03, 38.79it/s]
#  25% 38/150 [00:00<00:02, 39.69it/s]
#  28% 42/150 [00:01<00:02, 39.70it/s]
#  31% 46/150 [00:01<00:02, 38.20it/s]
#  33% 50/150 [00:01<00:02, 38.45it/s]
#  36% 54/150 [00:01<00:02, 38.89it/s]
#  39% 58/150 [00:01<00:02, 38.77it/s]
#  42% 63/150 [00:01<00:02, 39.41it/s]
#  45% 68/150 [00:01<00:02, 40.16it/s]
#  49% 73/150 [00:01<00:01, 39.66it/s]
#  51% 77/150 [00:01<00:01, 39.49it/s]
#  55% 82/150 [00:02<00:01, 40.09it/s]
#  58% 87/150 [00:02<00:01, 39.70it/s]
#  61% 91/150 [00:02<00:01, 38.71it/s]
#  64% 96/150 [00:02<00:01, 39.62it/s]
#  67% 100/150 [00:02<00:01, 39.43it/s]
#  70% 105/150 [00:02<00:01, 39.44it/s]
#  73% 109/150 [00:02<00:01, 39.03it/s]
#  75% 113/150 [00:02<00:00, 38.34it/s]
#  79% 118/150 [00:03<00:00, 38.75it/s]
#  81% 122/150 [00:03<00:00, 38.80it/s]
#  84% 126/150 [00:03<00:00, 38.82it/s]
#  87% 130/150 [00:03<00:00, 38.85it/s]
#  89% 134/150 [00:03<00:00, 39.07it/s]
#  92% 138/150 [00:03<00:00, 38.30it/s]
#  95% 142/150 [00:03<00:00, 38.66it/s]
#
# {'eval_loss': 0.0005019787349738181, 'eval_macro_f1': 1.0, 'eval_runtime': 3.854, 'eval_samples_per_second': 622.724, 'eval_steps_per_second': 38.92, 'epoch': 2.0}
#  67% 1050/1575 [02:46<01:03,  8.21it/s]
# 100% 150/150 [00:03<00:00, 38.76it/s]
# {'loss': 0.0009, 'grad_norm': 0.00988121796399355, 'learning_rate': 6.044444444444445e-06, 'epoch': 2.1}
# {'loss': 0.0008, 'grad_norm': 0.009051302447915077, 'learning_rate': 5.40952380952381e-06, 'epoch': 2.19}
# {'loss': 0.0008, 'grad_norm': 0.01034457515925169, 'learning_rate': 4.774603174603175e-06, 'epoch': 2.29}
# {'loss': 0.0008, 'grad_norm': 0.006655309349298477, 'learning_rate': 4.13968253968254e-06, 'epoch': 2.38}
# {'loss': 0.0079, 'grad_norm': 0.008437140844762325, 'learning_rate': 3.504761904761905e-06, 'epoch': 2.48}
# {'loss': 0.0007, 'grad_norm': 0.015889771282672882, 'learning_rate': 2.8698412698412703e-06, 'epoch': 2.57}
# {'loss': 0.0007, 'grad_norm': 0.008880054578185081, 'learning_rate': 2.234920634920635e-06, 'epoch': 2.67}
# {'loss': 0.0007, 'grad_norm': 0.009384870529174805, 'learning_rate': 1.6000000000000001e-06, 'epoch': 2.76}
# {'loss': 0.0007, 'grad_norm': 0.008362438529729843, 'learning_rate': 9.650793650793652e-07, 'epoch': 2.86}
# {'loss': 0.0007, 'grad_norm': 0.009020348079502583, 'learning_rate': 3.301587301587302e-07, 'epoch': 2.95}
# 100% 1575/1575 [04:42<00:00,  8.77it/s]
#   0% 0/150 [00:00<?, ?it/s]
#   4% 6/150 [00:00<00:03, 47.76it/s]
#   7% 11/150 [00:00<00:03, 42.56it/s]
#  11% 16/150 [00:00<00:03, 40.35it/s]
#  14% 21/150 [00:00<00:03, 38.55it/s]
#  17% 26/150 [00:00<00:03, 39.36it/s]
#  20% 30/150 [00:00<00:03, 39.34it/s]
#  23% 35/150 [00:00<00:02, 40.05it/s]
#  27% 40/150 [00:00<00:02, 40.20it/s]
#  30% 45/150 [00:01<00:02, 39.50it/s]
#  33% 50/150 [00:01<00:02, 40.27it/s]
#  37% 55/150 [00:01<00:02, 40.56it/s]
#  40% 60/150 [00:01<00:02, 40.33it/s]
#  43% 65/150 [00:01<00:02, 40.95it/s]
#  47% 70/150 [00:01<00:01, 41.29it/s]
#  50% 75/150 [00:01<00:01, 39.97it/s]
#  53% 80/150 [00:01<00:01, 40.56it/s]
#  57% 85/150 [00:02<00:01, 40.98it/s]
#  60% 90/150 [00:02<00:01, 40.47it/s]
#  63% 95/150 [00:02<00:01, 41.03it/s]
#  67% 100/150 [00:02<00:01, 41.16it/s]
#  70% 105/150 [00:02<00:01, 40.86it/s]
#  73% 110/150 [00:02<00:00, 40.06it/s]
#  77% 115/150 [00:02<00:00, 40.24it/s]
#  80% 120/150 [00:02<00:00, 40.13it/s]
#  83% 125/150 [00:03<00:00, 39.92it/s]
#  87% 130/150 [00:03<00:00, 40.06it/s]
#  90% 135/150 [00:03<00:00, 40.74it/s]
#  93% 140/150 [00:03<00:00, 39.85it/s]
#  96% 144/150 [00:03<00:00, 39.77it/s]
#
# {'eval_loss': 0.0003998348256573081, 'eval_macro_f1': 1.0, 'eval_runtime': 3.7758, 'eval_samples_per_second': 635.622, 'eval_steps_per_second': 39.726, 'epoch': 3.0}
# 100% 1575/1575 [04:46<00:00,  8.77it/s]
# 100% 150/150 [00:03<00:00, 40.73it/s]
# {'train_runtime': 366.1675, 'train_samples_per_second': 68.821, 'train_steps_per_second': 4.301, 'train_loss': 0.10306820336906683, 'epoch': 3.0}
# 100% 1575/1575 [06:06<00:00,  4.30it/s]
# 100% 150/150 [00:03<00:00, 40.96it/s]
# 100% 75/75 [00:01<00:00, 39.17it/s]
# Validation macro-F1: 1.0000
# Frozen test macro-F1: 1.0000
# Train time: 366.57s
# Saved artefact to: artifacts/topic_classifier

# %%
# !pytest tests/test_model_data.py -q
# Out:
# .                                                                        [100%]
# 1 passed in 1.33s

# %%
# !python scripts/tfidf_baseline.py
# Out:
# Validation macro-F1: 1.0000
# Frozen test macro-F1: 1.0000
# Train time: 0.33s

# %%
# !python scripts/train_ner.py --output-dir artifacts/ner
# Out:
# 2026-09-08 18:59:50.701754: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 190kB/s]
# config.json: 100% 615/615 [00:00<00:00, 4.54MB/s]
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 43.6MB/s]
# tokenizer.json: 9.10MB [00:00, 56.8MB/s]
# Map: 100% 2800/2800 [00:00<00:00, 14247.48 examples/s]
# Map: 100% 800/800 [00:00<00:00, 10577.35 examples/s]
# Map: 100% 400/400 [00:00<00:00, 11980.47 examples/s]
# model.safetensors: 100% 1.12G/1.12G [00:05<00:00, 202MB/s]
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# {'loss': 0.249, 'grad_norm': 0.05991203337907791, 'learning_rate': 2.832e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.012197023257613182, 'learning_rate': 2.6605714285714286e-05, 'epoch': 0.57}
# {'loss': 0.0014, 'grad_norm': 0.008844282478094101, 'learning_rate': 2.4891428571428572e-05, 'epoch': 0.86}
#  20% 175/875 [00:19<01:14,  9.44it/s]
#   0% 0/50 [00:00<?, ?it/s]
#  12% 6/50 [00:00<00:00, 57.43it/s]
#  24% 12/50 [00:00<00:00, 51.64it/s]
#  36% 18/50 [00:00<00:00, 50.49it/s]
#  48% 24/50 [00:00<00:00, 49.89it/s]
#  60% 30/50 [00:00<00:00, 49.73it/s]
#  70% 35/50 [00:00<00:00, 49.69it/s]
#  80% 40/50 [00:00<00:00, 49.73it/s]
#
# {'eval_loss': 0.0001824011851567775, 'eval_entity_f1': 1.0, 'eval_runtime': 1.0892, 'eval_samples_per_second': 734.517, 'eval_steps_per_second': 45.907, 'epoch': 1.0}
#  20% 175/875 [00:20<01:14,  9.44it/s]
# 100% 50/50 [00:01<00:00, 49.65it/s]
# {'loss': 0.0026, 'grad_norm': 0.3739456534385681, 'learning_rate': 2.317714285714286e-05, 'epoch': 1.14}
# {'loss': 0.2251, 'grad_norm': 1.1498754024505615, 'learning_rate': 2.1462857142857145e-05, 'epoch': 1.43}
# {'loss': 0.0796, 'grad_norm': 0.7499183416366577, 'learning_rate': 1.9748571428571427e-05, 'epoch': 1.71}
# {'loss': 0.0532, 'grad_norm': 0.4091572165489197, 'learning_rate': 1.8034285714285713e-05, 'epoch': 2.0}
#  40% 350/875 [01:00<00:57,  9.13it/s]
#   0% 0/50 [00:00<?, ?it/s]
#  12% 6/50 [00:00<00:00, 51.41it/s]
#  24% 12/50 [00:00<00:00, 50.03it/s]
#  36% 18/50 [00:00<00:00, 48.59it/s]
#  46% 23/50 [00:00<00:00, 47.42it/s]
#  56% 28/50 [00:00<00:00, 47.49it/s]
#  66% 33/50 [00:00<00:00, 47.96it/s]
#  76% 38/50 [00:00<00:00, 48.07it/s]
#  86% 43/50 [00:00<00:00, 47.45it/s]
#
# {'eval_loss': 0.055085115134716034, 'eval_entity_f1': 0.9598080383923215, 'eval_runtime': 1.0934, 'eval_samples_per_second': 731.694, 'eval_steps_per_second': 45.731, 'epoch': 2.0}
#  40% 350/875 [01:01<00:57,  9.13it/s]
# 100% 50/50 [00:01<00:00, 47.17it/s]
# {'loss': 0.0538, 'grad_norm': 0.45625215768814087, 'learning_rate': 1.6320000000000003e-05, 'epoch': 2.29}
# {'loss': 0.0506, 'grad_norm': 0.3106020390987396, 'learning_rate': 1.4605714285714287e-05, 'epoch': 2.57}
# {'loss': 0.054, 'grad_norm': 0.19440242648124695, 'learning_rate': 1.2891428571428572e-05, 'epoch': 2.86}
#  60% 525/875 [01:43<00:37,  9.27it/s]
#   0% 0/50 [00:00<?, ?it/s]
#  12% 6/50 [00:00<00:00, 57.59it/s]
#  24% 12/50 [00:00<00:00, 49.36it/s]
#  36% 18/50 [00:00<00:00, 48.32it/s]
#  46% 23/50 [00:00<00:00, 46.86it/s]
#  56% 28/50 [00:00<00:00, 46.84it/s]
#  66% 33/50 [00:00<00:00, 46.61it/s]
#  76% 38/50 [00:00<00:00, 46.13it/s]
#  86% 43/50 [00:00<00:00, 46.11it/s]
#
# {'eval_loss': 0.05228574201464653, 'eval_entity_f1': 0.9597718402882017, 'eval_runtime': 1.1509, 'eval_samples_per_second': 695.083, 'eval_steps_per_second': 43.443, 'epoch': 3.0}
#  60% 525/875 [01:44<00:37,  9.27it/s]
# 100% 50/50 [00:01<00:00, 45.62it/s]
# {'loss': 0.0529, 'grad_norm': 0.39839211106300354, 'learning_rate': 1.1177142857142856e-05, 'epoch': 3.14}
# {'loss': 0.1241, 'grad_norm': 0.7489686012268066, 'learning_rate': 9.462857142857144e-06, 'epoch': 3.43}
# {'loss': 0.1342, 'grad_norm': 0.744459331035614, 'learning_rate': 7.748571428571429e-06, 'epoch': 3.71}
# {'loss': 0.1522, 'grad_norm': 0.4892882704734802, 'learning_rate': 6.034285714285715e-06, 'epoch': 4.0}
#  80% 700/875 [02:45<00:19,  9.16it/s]
#   0% 0/50 [00:00<?, ?it/s]
#  12% 6/50 [00:00<00:00, 55.30it/s]
#  24% 12/50 [00:00<00:00, 47.83it/s]
#  34% 17/50 [00:00<00:00, 46.93it/s]
#  44% 22/50 [00:00<00:00, 45.46it/s]
#  54% 27/50 [00:00<00:00, 44.93it/s]
#  64% 32/50 [00:00<00:00, 45.05it/s]
#  74% 37/50 [00:00<00:00, 44.48it/s]
#  84% 42/50 [00:00<00:00, 44.56it/s]
#
# {'eval_loss': 0.15242637693881989, 'eval_entity_f1': 0.8623529411764705, 'eval_runtime': 1.148, 'eval_samples_per_second': 696.873, 'eval_steps_per_second': 43.555, 'epoch': 4.0}
#  80% 700/875 [02:46<00:19,  9.16it/s]
# 100% 50/50 [00:01<00:00, 44.34it/s]
# {'loss': 0.1354, 'grad_norm': 0.7613568305969238, 'learning_rate': 4.32e-06, 'epoch': 4.29}
# {'loss': 0.1406, 'grad_norm': 0.6095503568649292, 'learning_rate': 2.605714285714286e-06, 'epoch': 4.57}
# {'loss': 0.1387, 'grad_norm': 0.4447190761566162, 'learning_rate': 8.914285714285714e-07, 'epoch': 4.86}
# 100% 875/875 [03:37<00:00,  8.82it/s]
#   0% 0/50 [00:00<?, ?it/s]
#  12% 6/50 [00:00<00:00, 53.26it/s]
#  24% 12/50 [00:00<00:00, 45.69it/s]
#  34% 17/50 [00:00<00:00, 44.44it/s]
#  44% 22/50 [00:00<00:00, 43.63it/s]
#  54% 27/50 [00:00<00:00, 43.09it/s]
#  64% 32/50 [00:00<00:00, 42.87it/s]
#  74% 37/50 [00:00<00:00, 42.38it/s]
#  84% 42/50 [00:00<00:00, 42.26it/s]
#
# {'eval_loss': 0.15003974735736847, 'eval_entity_f1': 0.8623529411764705, 'eval_runtime': 1.2677, 'eval_samples_per_second': 631.064, 'eval_steps_per_second': 39.442, 'epoch': 5.0}
# 100% 875/875 [03:38<00:00,  8.82it/s]
# 100% 50/50 [00:01<00:00, 42.32it/s]
# {'train_runtime': 260.5991, 'train_samples_per_second': 53.722, 'train_steps_per_second': 3.358, 'train_loss': 0.09805097539935793, 'epoch': 5.0}
# 100% 875/875 [04:20<00:00,  3.36it/s]
# 100% 50/50 [00:01<00:00, 42.66it/s]
# 100% 25/25 [00:00<00:00, 44.83it/s]
# Validation entity-F1: 1.0000
# Frozen test entity-F1: 1.0000
# Train time: 261.02s
# Saved artefact to: artifacts/ner

# %% [markdown]
# ## 4. Optional but recommended: persist large training artefacts in Google Drive
# Colab runtimes are temporary. Mount Drive before long training so model artefacts survive a runtime reset. Code, tests, benchmark tables and decisions still belong in GitHub; large weights can live outside Git.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1242/907070862.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.13/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.13/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
from pathlib import Path

DRIVE_ARTIFACT_ROOT = Path('/content/drive/MyDrive/DaicoNlp/artifacts')
DRIVE_ARTIFACT_ROOT.mkdir(parents=True, exist_ok=True)
print('Persistent artefacts:', DRIVE_ARTIFACT_ROOT)

# %% [markdown]
# ## 5. GPU lab pattern
# When Labs 3–4 ask you to train, run the repository script rather than rewriting training logic in the notebook. The scripts expose output paths so the same code works locally or in Colab. Example pattern (do not run until that lab is implemented):
#
# ```bash
# python scripts/train_classifier.py --output-dir /content/drive/MyDrive/SDA-AIE-211/artifacts/topic_classifier
# ```
#
# After a run, commit/push **code + measured evidence**, not large model binaries.

# %% [markdown]
# ## 6. Sync your code
# At the beginning of a new Colab session: clone the repository again (or `git pull` if the runtime still exists). At the end of work: commit and push the code/evidence required by the lab.
